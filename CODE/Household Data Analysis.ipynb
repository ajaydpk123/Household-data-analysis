# %% [markdown]
# #DPY - 2001 Week 2 - Mandatory Project
# Data consists of 20640 rows and 10 features:
#
# longitude: A measure of how far west a house is; a higher value is farther west
#
# latitude: A measure of how far north a house is; a higher value is farther north
#
#
# housingMedianAge: Median age of a house within a block; a lower number is a newer building
# totalRooms: Total number of rooms within a block
#
# totalBedrooms: Total number of bedrooms within a block
#
# population: Total number of people residing within a block
#
# households: Total number of households, a group of people residing within a home unit, for a block
#
# medianIncome: Median income for households within a block of houses (measured in tens of thousands of US Dollars)
#
# medianHouseValue: Median house value for households within a block (measured in US Dollars)
#
# oceanProximity: Location of the

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
housing = pd.read_excel('/housing.xlsx')
housing.head(20)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# 5     -122.25     37.85                52.0        919.0           213.0
# 6     -122.25     37.84                52.0       2535.0           489.0
# 7     -122.25     37.84                52.0       3104.0           687.0
# 8     -122.26     37.84                42.0       2555.0           665.0
# 9     -122.25     37.84                52.0       3549.0           707.0
# 10    -122.26     37.85                52.0       2202.0           434.0
# 11    -122.26     37.85                52.0       3503.0           752.0
# ...

# %%
# QUESTION 1:What is the average median income of the data set and check the distribution of data using appropriate plots.
#            Please explain the distribution of the plot.

# %%
housing['median_income'].mean()
# Out:
# 3.8706710029069766

# %%
#QUESTION 2: Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.
housing['housing_median_age'].hist(bins=50)


#From the observation , we can see that most of the houses are dispersed 
#between 10 to 40 with few houses exceptionally standing out as outlash which are above 50 years

# %%
# QUESTION3: Show with the help of visualization, how median_income and median_house_values are related?
housing.plot(kind = 'scatter', x= 'median_income', y= 'median_house_value')

#It is an obvious that the house price has a correlation with median income.And house price is directly proportional to
#median income

# %%
#QUESTION4:  Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.
housing.isnull().sum()
housingf = housing.dropna()
housingf.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
 #QUESTION5: Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.
housing.isnull().sum()
housing1 = housing.fillna(value=housing['total_bedrooms'].mean())
housing1.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#QUESTION6: Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.
def median(list_of_nums):
  list_of_nums.sort()
  if len(list_of_nums) % 2 != 0:
   middle_index = int((len(list_of_nums)-1) / 2)
   return list_of_nums[middle_index]
  elif len(list_of_nums) % 2 == 0:
   middle_index_1 = int(len(list_of_nums) / 2)
   middle_index_2 = int(len(list_of_nums) / 2)-1
   return (list_of_nums[middle_index_1] + list_of_nums[middle_index_2])/2

 
print(median([13,13,13,13,14,14,16,18]))
# Out:
# 13.5

# %%
#QUESTION7: Plot latitude versus longitude and explain your observations.
housing.plot(kind = 'scatter', x= 'latitude', y= 'longitude')

# %%
#QUESTION 8: Create a data set for which the ocean_proximity is ‘Near ocean’.
dataset = housing['ocean_proximity'] == 'NEAR OCEAN'
ds = housing[dataset]
ds
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                16.0       2739.0           480.0
# 1851     -124.30     41.80                19.0       2672.0           552.0
# 1852     -124.23     41.75                11.0       3159.0           616.0
# 1853     -124.21     41.77                17.0       3461.0           722.0
# 1854     -124.19     41.78                15.0       3140.0           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                16.0       1316.0           194.0
# 20381    -118.83     34.14                16.0       1956.0           312.0
# 20423    -119.00     34.08                17.0       1822.0           438.0
# 20424    -118.75     34.18                 4.0      16704.0          2704.0
# 20425    -118.75     34.17                18.0       6217.0           858.0
#
# ...

# %%
#QUESTION9 : Find the mean and median of the median income for the data set created in question 8.
print(ds['median_income'].mean())
print(ds['median_income'].median())
# Out:
# 4.0057848006019565
# 3.64705

# %%
#QUESTION10: Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. 
#If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.
housing.loc[housing['total_bedrooms']<=10 , 'total_bedroom_size'] = 'small'
housing.loc[(housing['total_bedrooms']>=11) & (housing['total_bedrooms']<1000) , 'total_bedroom_size'] = 'medium'
housing.loc[housing['total_bedrooms'] >=1000, 'total_bedroom_size'] = 'large'
print(housing.head(20))
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# 5     -122.25     37.85                52.0        919.0           213.0
# 6     -122.25     37.84                52.0       2535.0           489.0
# 7     -122.25     37.84                52.0       3104.0           687.0
# 8     -122.26     37.84                42.0       2555.0           665.0
# 9     -122.25     37.84                52.0       3549.0           707.0
# 10    -122.26     37.85                52.0       2202.0           434.0
# 11    -122.26     37.85                52.0       3503.0           752.0
# ...
